# %% [markdown]
# <a href="https://colab.research.google.com/github/mpt777/CS474/blob/main/lab7_Translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clone()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext spacy
# !python -m spacy download en
# !python -m spacy download es
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Requirement already satisfied: torchtext in /usr/local/lib/python3.7/dist-packages (0.3.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext) (4.41.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.7.1+cu101)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.19.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (54.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchtext) (3.7.4.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2020.12.5)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (3.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.4.0)
# Requirement already satisfied: en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5 in /usr/local/lib/python3.7/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (54.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2020.12.5)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.4.3)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# Requirement already satisfied: es_core_news_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.2.5/es_core_news_sm-2.2.5.tar.gz#egg=es_core_news_sm==2.2.5 in /usr/local/lib/python3.7/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from es_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.8.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.19.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (54.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (4.41.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.5)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.4.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/es_core_news_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/es
# You can now load the model via spacy.load('es')
# --2021-03-06 18:11:22--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  50.5MB/s    in 0.2s
#
# 2021-03-06 18:11:22 (50.5 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2021-03-06 18:11:22--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  47.6MB/s    in 0.2s
#
# 2021-03-06 18:11:23 (47.6 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# #Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ##Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention'
    donkey_kong = query.shape[2]
    # scores = QK^T/scale
    scores = torch.matmul( query, key.permute(0, 2, 1) ) * 1/np.sqrt(donkey_kong) 
    
    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
        
    # output = softmax(scores)(V)
    output = torch.matmul( F.softmax(scores, dim = -1), value )

    return output

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        # Implement Multi-head attention mechanism
        self.dropout = nn.Dropout(dropout)

        # Make an attention head (linear layers for q, k, and v)
        self.attention_head = nn.Linear( d_model, d_model//h ).cuda()

        # Make h copies of the attention head (Hint: See the `clone()` helper function)
        self.attention_heads = [clones(self.attention_head, 3) for i in range(h)]
        self.output = nn.Linear(d_model, d_model)

    def forward(self, query, key, value, mask):
        # Pass the query, key, value through their respective layers
        outputs = []
        for head in self.attention_heads:
            q_pass, k_pass, v_pass = ( head[0](query), head[1](key), head[2](value) )
            # Compute scaled dot-product attention on the output
            outputs.append( attention(q_pass, k_pass, v_pass, mask) )

        multi_attention_heads = self.output( self.dropout(torch.cat(outputs, 2) ) )

        return multi_attention_heads

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es')
spacy_en = spacy.load('en')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
spanish_text = open('./spanish','r')
english_text = open('./english', 'r')
english_lines = list(english_text)
spanish_lines = list(spanish_text)

fields = (["src", SRC], ["trg", TGT])
examples = [torchtext.data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = torchtext.data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ##Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        run_epoch((rebatch(pad_idx, b) for b in train_iter), 
                  model, 
                  LossFunction(model.generator, criterion, model_opt))
        model.eval()
scope()
# Out:
# Epoch Step: 1 Loss: 8.696390 Tokens per Sec: 4079.281250
# Epoch Step: 51 Loss: 5.721965 Tokens per Sec: 10723.151367
# Epoch Step: 101 Loss: 5.586607 Tokens per Sec: 11057.109375
# Epoch Step: 151 Loss: 5.555277 Tokens per Sec: 10995.445312
# Epoch Step: 201 Loss: 5.305005 Tokens per Sec: 11181.656250
# Epoch Step: 251 Loss: 5.054970 Tokens per Sec: 10951.595703
# Epoch Step: 301 Loss: 4.716469 Tokens per Sec: 11135.290039
# Epoch Step: 351 Loss: 4.465767 Tokens per Sec: 10820.011719
# Epoch Step: 401 Loss: 4.985136 Tokens per Sec: 11229.327148
# Epoch Step: 451 Loss: 5.182648 Tokens per Sec: 11072.305664
# Epoch Step: 501 Loss: 4.399519 Tokens per Sec: 11359.073242
# Epoch Step: 551 Loss: 4.666344 Tokens per Sec: 10731.926758
# Epoch Step: 601 Loss: 4.308746 Tokens per Sec: 11225.485352
# Epoch Step: 651 Loss: 3.955507 Tokens per Sec: 10866.318359
# Epoch Step: 701 Loss: 4.406023 Tokens per Sec: 11019.473633
# Epoch Step: 751 Loss: 4.328811 Tokens per Sec: 11246.282227
# Epoch Step: 801 Loss: 4.330710 Tokens per Sec: 11095.491211
# Epoch Step: 851 Loss: 3.902444 Tokens per Sec: 11345.818359
# Epoch Step: 901 Loss: 4.089269 Tokens per Sec: 10933.161133
# Epoch Step: 951 Loss: 3.888472 Tokens per Sec: 11151.086914
# Epoch Step: 1001 Loss: 4.594095 Tokens per Sec: 11143.848633
# Epoch Step: 1051 Loss: 3.856258 Tokens per Sec: 11213.554688
# Epoch Step: 1101 Loss: 3.601649 Tokens per Sec: 11256.264648
# Epoch Step: 1151 Loss: 3.482711 Tokens per Sec: 11177.782227
# Epoch Step: 501 Loss: 2.711130 Tokens per Sec: 11233.605469
# Epoch Step: 551 Loss: 1.918908 Tokens per Sec: 10969.848633
# Epoch Step: 601 Loss: 3.125196 Tokens per Sec: 10809.347656
# Epoch Step: 651 Loss: 2.882093 Tokens per Sec: 11164.343750
# Epoch Step: 701 Loss: 2.506153 Tokens per Sec: 10997.891602
# Epoch Step: 751 Loss: 2.580082 Tokens per Sec: 10827.726562
# Epoch Step: 801 Loss: 2.763574 Tokens per Sec: 11106.602539
# Epoch Step: 851 Loss: 3.029442 Tokens per Sec: 11136.621094
# Epoch Step: 901 Loss: 2.263769 Tokens per Sec: 11300.458984
# Epoch Step: 951 Loss: 2.933630 Tokens per Sec: 10863.041992
# Epoch Step: 1001 Loss: 2.805536 Tokens per Sec: 11078.716797
# Epoch Step: 1051 Loss: 2.369003 Tokens per Sec: 10774.152344
# Epoch Step: 1101 Loss: 4.349446 Tokens per Sec: 11126.244141
# Epoch Step: 1151 Loss: 2.504318 Tokens per Sec: 11120.333984
# Epoch Step: 1201 Loss: 2.887034 Tokens per Sec: 11225.791992
# Epoch Step: 1251 Loss: 2.869820 Tokens per Sec: 11004.279297
# Epoch Step: 1301 Loss: 2.694092 Tokens per Sec: 11298.070312

# %% [markdown]
# ## Translate

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	Debemos contraatacar
# Translation:	We must stop trying to turn to
# Target:		We Must Fight Back
#
# Spanish:	Sesión del sacerdocio
# Translation:	Priesthood Session
# Target:		Priesthood Session
#
# Spanish:	Sabemos por qué
# Translation:	We know why we know why
# Target:		We Know Why
#
# Spanish:	Guíenme , <unk>
# Translation:	Let me , I ’ll Go ,
# Target:		Lead me , guide me , walk beside me ,
#
# Spanish:	Mamá me lo dijo
# Translation:	I did I said me me me me me me me me me me me me me me me me me me .
# Target:		Mother <unk> Me
#
# Spanish:	Presidente Gordon B. Hinckley
# Translation:	President Gordon B. Hinckley
# Target:		President Gordon B. Hinckley
#
# Spanish:	¿ Ustedes no ?
# Translation:	You do not ?
# Target:		Do n’t you ?
#
# Spanish:	Quizá sí ” .
# Translation:	You may be ” . ”
# Target:		Perhaps he could . ”
#
# Spanish:	Tienen seis hijos .
# Translation:	You have six children .
# Target:		They are the parents of six children .
#
# Spanish:	¡ Funciona de maravilla !
# Translation:	It !
# Target:		It Works Wonderfully !
#
# Spanish:	Doctrina y Convenios <unk> .
# Translation:	Doctrine and Covenants 20:37 .
# Target:		Doctrine and Covenants <unk> .
#
# Spanish:	Arrepentimiento : Una gozosa elección
# Translation:	A Choice :
# Target:		Repentance : A Joyful Choice
#
# Spanish:	Una necesidad y un deber
# Translation:	A need a need a duty and duty and
# Target:		A Need and a Duty
#
# Spanish:	y repetirla sin vacilar .
# Translation:	And they are not afraid .
# Target:		And quote it back again .
#
# Spanish:	Sesión del domingo por la mañana
# Translation:	Sunday Morning Session
# Target:		Sunday Morning Session
#
# Spanish:	Por el élder Quentin L. Cook
# Translation:	By Elder Quentin L. Cook
# Target:		By Elder Quentin L. Cook
#
# Spanish:	Por el élder Donald L. Hallstrom
# Translation:	By Elder L. Hallstrom
# Target:		By Elder Donald L. Hallstrom
#
# Spanish:	Véase Doctrina y Convenios 6:37 .
# Translation:	See Doctrine and Covenants 20:37 .
# Target:		See Doctrine and Covenants 6:37 .
#
# Spanish:	Véase D. y C. 101:16 .
# Translation:	See Doctrine and Covenants 20:37 .
# Target:		See Doctrine and Covenants 101:16 .
#
# Spanish:	Para que se haga fuerte también
# Translation:	For you do n’t fear not fear not
# Target:		That He May Become Strong Also
#
# Spanish:	Del Quórum de los Doce Apóstoles
# Translation:	Of the Quorum of the Twelve Apostles
# Target:		Of the Quorum of the Twelve Apostles
#
# Spanish:	nuestro <unk> en alto plantar ,
# Translation:	Our Time , in a stranger ,
# Target:		Stand by our colors ; proudly they wave !
#
# Spanish:	Uno de los hijos se <unk> .
# Translation:	One children are the children .
# Target:		One son became inactive .
#
# Spanish:	Véase José Smith — Historia 1:15–17 .
# Translation:	See Joseph Smith — History 1:19 .
# Target:		See Joseph Smith — History 1:15–17 .
#
# Spanish:	Llamados a servir y asignados a trabajar
# Translation:	First Counselor and I am to serve and to work to work to work
# Target:		Called to Serve and Assigned to <unk>
#
# Spanish:	Hicieron eso debido a sus creencias .
# Translation:	They did because his beliefs .
# Target:		You did that because of your beliefs .
#
# Spanish:	<unk> sus asignaciones completa y cabalmente .
# Translation:	They were strong and happy and happy .
# Target:		They carried out their assignments completely and fully .
#
# Spanish:	siempre ha sido y lo será .
# Translation:	It has always been and be .
# Target:		It has always been thus , and it ever will be .
#
# Spanish:	“ Me veo a mí mismo ” .
# Translation:	“ I see me . ”
# Target:		“ I see me . ”
#
# Spanish:	¿ Por qué enseñó Jesús estas parábolas ?
# Translation:	Why taught this taught this :
# Target:		Why did Jesus teach these parables ?
#
# Spanish:	pero John insistió , así que fui .
# Translation:	But John taught , I was so I was so .
# Target:		But John insisted , so I went .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	Fue llamado como Autoridad General en 1997 .
# Translation:	It was called as a General Authority Seventy .
# Target:		He was called as a General Authority in 1997 .
#
# Spanish:	y siempre guardarlo , y siempre guardarlo ,
# Translation:	I will always remember , and I will I will I will always , and I will always , and I will always , and I will always , and I will always , and I will .
# Target:		I ’ll never , no never , I ’ll never , no never ,
#
# Spanish:	Tercero : Obtengan gozo en el servicio del sacerdocio
# Translation:	Third , a joy in the priesthood service of priesthood service .
# Target:		Third : Find Joy in Priesthood Service
#
# Spanish:	Eso es exactamente lo que hizo Wilford Woodruff .
# Translation:	This is right because Wilford Woodruff .
# Target:		That is exactly what Wilford Woodruff did .
#
# Spanish:	Adviértase que estos siete versículos forman una frase .
# Translation:	They were in these history .
# Target:		Note that these seven verses comprise one sentence .
#
# Spanish:	2 . Para pelear , se necesitan dos personas
# Translation:	To Boyd K. Packer , two people need two people .
# Target:		2 . To <unk> , You Need Two People
#
# Spanish:	Vengan , <unk> y reciban el Espíritu Santo .
# Translation:	Come , and Covenants will receive the Holy Ghost .
# Target:		Come and be baptized and receive the Holy Ghost .
#
# Spanish:	No sólo progresarán ellos , sino ustedes también .
# Translation:	Not only will not be but also you .
# Target:		Not only will they grow ; you will grow too .
#
# Spanish:	Si escoges comer , elegirás helado de <unk> .
# Translation:	If you do you do n’t think about it .
# Target:		If you choose to eat dinner , you are choosing ice cream for <unk> .
#
# Spanish:	Esta semana volví a subir el monte Ensign Peak .
# Translation:	This week I found the mountain ’ mountain mountain to the Bible .
# Target:		This week I again climbed Ensign Peak .
#
# Spanish:	¿ Qué bendiciones recibimos al escuchar a nuestros padres ?
# Translation:	What promises to the blessings to hear our parents ?
# Target:		What blessings come from listening to our parents ?
#
# Spanish:	Verdaderamente es proveer conforme a la manera del Señor .
# Translation:	It is to Church as the Lord ’s way .
# Target:		It truly is providing in the Lord ’s way .
#
# Spanish:	En ello también vemos una semejanza con lo divino .
# Translation:	In fact , we see a divine love .
# Target:		Here too we see another comparison with the divine .
#
# Spanish:	Permítanme enseñarles algo de otra experiencia de mi vida :
# Translation:	Let me share something of these experience : I share with my life :
# Target:		Let me teach you from another experience of my life :
#
# Spanish:	Descendió debajo de todo para salvar todas las cosas .
# Translation:	He was born from all things .
# Target:		He passed beneath all things that He might save all things .
#
# Spanish:	Ustedes tendrán experiencias sagradas , igual que ese joven .
# Translation:	You have sacred experiences , as young man .
# Target:		You will have sacred experiences , just as this young man did .
#
# Spanish:	Segunda Consejera en la Presidencia General de la Sociedad de Socorro
# Translation:	Second Counselor in the Relief Society General Presidency
# Target:		Second Counselor in the Relief Society General Presidency
#
# Spanish:	Mis queridos hermanos y hermanas , ¡ mis queridos amigos !
# Translation:	My dear brothers and sisters , I love me !
# Target:		My dear brothers and sisters , my dear friends !
#
# Spanish:	Ya van cuatro generaciones de esa familia que resultan afectadas .
# Translation:	You are four generations that the family who are the people .
# Target:		Four generations of the family have now been affected .
#
# Spanish:	Al sufrir tribulaciones , nos es posible comprender la paz .
# Translation:	As we suffer trials , we may understand that we hope .
# Target:		We are able to understand peace because we feel turmoil .
#
# Spanish:	Tres años después , volvió con su familia a Utah .
# Translation:	Three years later , after his family .
# Target:		He returned to Utah with his family three years later .
#
# Spanish:	Él nos conoce y dio Su vida por Sus ovejas .
# Translation:	He knows us and His life for His sheep .
# Target:		He knows us and laid down His life for His sheep .
#
# Spanish:	Contrarios , si los hay , con la misma señal .
# Translation:	Contrary , if there is there with the same sign .
# Target:		Contrary , if there be any , by the same sign .
#
# Spanish:	Digo estas cosas en el nombre de Jesucristo . Amén .
# Translation:	I say these things in the name of Jesus Christ , amen .
# Target:		I say these things in the name of Jesus Christ , amen .
#
# Spanish:	Sé que seguirá siendo una bendición a medida que crezca .
# Translation:	I know that you will be a blessing as you will be in .
# Target:		I know that he will continue to be a blessing as he gets older .
#
# Spanish:	No obstante , a veces creo que comprendemos mal la obediencia .
# Translation:	However , I think we think that obedience .
# Target:		But sometimes I think we misunderstand obedience .
#
# Spanish:	La obediencia permite que las bendiciones de Dios <unk> sin restricciones .
# Translation:	Obedience to the blessings that God ’s blessings .
# Target:		Obedience allows God ’s blessings to flow without constraint .
#
# Spanish:	Después de todo , “ la familia es ordenada por Dios .
# Translation:	After all of all the family is ordained of God .
# Target:		After all , “ the family is ordained of God .
#
# Spanish:	En ambas ocasiones la sanación de cuerpo y espíritu fue otorgada .
# Translation:	In many times the healing and spirit of spirit is our spirits .
# Target:		In both cases a healing of body and spirit was granted .
#
# Spanish:	Tercer paso : “ Camina en la mansedumbre de mi Espíritu ”
# Translation:	Conference Report , “ Ye Sons of thy Spirit of my Spirit ”
# Target:		Third Step : “ Walk in the Meekness of My Spirit ”
#
# Spanish:	Cuando hablamos con amor , el Espíritu puede estar con nosotros .
# Translation:	When we talk with love , you can be with us .
# Target:		When we speak in love , the Spirit can be with us .
#
# Spanish:	Eso se ha descrito como morir con la música por dentro .
# Translation:	This has taught that when he had the music .
# Target:		This has been described as dying with your music still inside you .
#
# Spanish:	Un relato conmovedor de obediencia es el de Abraham e Isaac .
# Translation:	A story of obedience is the foundation of Abraham and Abraham .
# Target:		A soul - stirring account of obedience is that of Abraham and Isaac .
#
# Spanish:	<unk> más y tuve el privilegio de <unk> a los dos .
# Translation:	I was more than the privilege of the two of two of two .
# Target:		They learned more , and it was my privilege to baptize both of them .
#
# Spanish:	Guía para la familia , folleto , 2001 , pág. 12 .
# Translation:	Home , Gospel , May 2001 , 2001 , 2011 , 2011 .
# Target:		Our Family : A Practical Guide for Building a Gospel - Centered Home ( pamphlet , 1980 ) , 6 .
#
# Spanish:	Domingo por la mañana , 4 de abril de 2010 , Sesión General
# Translation:	Sunday morning , April 2 , 2010 , 2010 , 2010 , 2010 , 2016 , 2016 , 2016 , 2016
# Target:		Sunday Morning , April 4 , 2010 , General Session
#
# Spanish:	El conflicto en Ucrania ha desplazado a millones de personas desde 2014 .
# Translation:	The destruction has served in the people of people .
# Target:		<unk> in Ukraine has displaced a million people since 2014 .
#
# Spanish:	Jeffrey R. Holland , Christ and the New Covenant , pág. <unk> .
# Translation:	Jeffrey R. Holland , Christ and the New Testament , Oct. 1994 .
# Target:		Jeffrey R. Holland , Christ and the New Covenant , <unk> .
#
# Spanish:	Su conocimiento de que nuestro Padre Celestial las ama y las cuida .
# Translation:	His knowledge of our Heavenly Father loves us and Covenants 20:37 .
# Target:		Your knowledge that Heavenly Father loves you and cares for you .
#
# Spanish:	Ese cambio , llamado conversión , es posible sólo mediante el Salvador .
# Translation:	That change , the call is only our Savior .
# Target:		This change , called conversion , is possible only through the Savior .
#
# Spanish:	El himno sacramental es una parte especialmente importante de la Santa Cena .
# Translation:	The sacrament is a new part of the sacrament .
# Target:		The sacrament hymn is an especially important part of our sacrament experience .
#
# Spanish:	“ Extendió su mano para estrechar la mía ” , recordó Corrie .
# Translation:	“ He invited his hand to his hand , ” he reminded him .
# Target:		“ His hand was thrust out to shake mine , ” Corrie recalled .
#
# Spanish:	Es importante reconocer que el propósito primordial de Dios es nuestro progreso .
# Translation:	It is important that the purpose of God is our progress .
# Target:		It is important to recognize that God ’s ultimate purpose is our progress .
#
# Spanish:	" No hay paz para los malvados , dice mi Dios " .
# Translation:	" There is no peace to the evil , " my God . "
# Target:		" There is no peace , saith my God , to the wicked . "
#
# Spanish:	Debemos reconocer que todos somos imperfectos , que somos mendigos ante Dios .
# Translation:	We must recognize that we are all of us , we are like God .
# Target:		We must recognize that we are all imperfect — that we are beggars before God .
#
# Spanish:	Elegimos creer cuando nos bautizamos y cuando participamos de la Santa Cena .
# Translation:	We are we are like to follow the sacrament and partake of the sacrament .
# Target:		We are choosing to believe when we are baptized and when we partake of the sacrament .
#
# Spanish:	Los templos de esta Iglesia son exactamente lo que se declara de ellos .
# Translation:	The Church entities disburse funds is right that which is the end of them .
# Target:		The temples of this Church are precisely as proclaimed .
#
# Spanish:	( 24 ) Jóvenes del Sacerdocio Aarónico enseñan una clase de historia familiar .
# Translation:	( 24 ) Young Women ’s First Presidency
# Target:		( 24 ) Aaronic Priesthood youth teach a family history class .
#
# Spanish:	Su magnífico sacrificio expiatorio tiene un sublime significado que trasciende el entendimiento humano .
# Translation:	His great sacrifice has a glorious significance that the human understanding .
# Target:		His magnificent atoning sacrifice is of transcendent significance beyond mortal comprehension .
#
# Spanish:	<unk> , pues , ¿ cuál de éstos le amará más ? ” .
# Translation:	To you , you , you do this more than you ? ”
# Target:		Tell me therefore , which of them will love him most ? ”
#
# Spanish:	Se habían comprometido a volver a empezar y a esforzarse más esta vez .
# Translation:	They had commanded to wait to start and more than this way .
# Target:		They were committed to beginning again and trying harder this time around .
#
# Spanish:	Señor , ¿ a quién iremos ? Tú tienes palabras de vida eterna .
# Translation:	Lord , “ Do you are to do ?
# Target:		To whom shall we go ? thou hast the words of eternal life .
#
# Spanish:	Ésa es una respuesta absolutamente inapropiada para alguien que ha leído este libro .
# Translation:	This is a response to someone who has read this book .
# Target:		That ’s a totally inappropriate response for one who has read this book .
#
# Spanish:	Me sorprendió que no entendiera lo que queremos decir con la palabra albedrío .
# Translation:	I was surprised that I did not believe that we want to say with agency .
# Target:		I was surprised he did not understand what we mean by the word agency .
#
# Spanish:	Sin embargo , no era un abrigo nuevo y estaba más bien <unk> .
# Translation:	However , it was not a new and more .
# Target:		However , it was n’t a new coat , and it was rather faded .
#
# Spanish:	Más que simplemente prohibir los ídolos físicos , establece una prioridad fundamental permanente .
# Translation:	More than we simply used a different priority , a vital information .
# Target:		More than merely <unk> physical idols , this states a fundamental priority for all time .
#
# Spanish:	¿ Necesita la oveja saber manejar un sextante complicado para calcular sus coordenadas ?
# Translation:	Do we need to know a sheep need to be able to be our own ?
# Target:		Does the sheep need to know how to use a complicated sextant to calculate its coordinates ?
#
# Spanish:	Jóvenes , ustedes saben que son mejores cuando están al servicio de Dios .
# Translation:	Young men know you know that are when God are like God .
# Target:		Young men , you know that you are at your best when you are in the service of God .
#
# Spanish:	El regreso de Elías el profeta bendijo a todos los que poseen el sacerdocio .
# Translation:	The sheep of Elijah has blessed to all the priesthood .
# Target:		The return of Elijah blessed all who hold the priesthood .
#
# Spanish:	Abraham , el padre de los fieles , experimentó la vida de manera diferente .
# Translation:	Abraham , the father of faithful , has lived a different way .
# Target:		Abraham , the father of the faithful , experienced life differently .
#
# Spanish:	Ningún pabellón <unk> el entendimiento de Eliza ni <unk> su perspectiva de la realidad .
# Translation:	No wonder the goal of their goal or her perspective .
# Target:		No pavilion obscured Eliza ’s understanding or <unk> her view of reality .
#
# Spanish:	El Salvador explicó la importancia de la identidad de ellos como hijos del convenio .
# Translation:	The Savior explained the importance of the identity as covenant children .
# Target:		The Savior explained the importance of their identity as children of the covenant .
#
# Spanish:	Ellos tienen que haber sentido su elogio genuino antes de que acepten su corrección .
# Translation:	They have felt that their way to do so that you have to bless your own .
# Target:		They must have felt your genuine praise before they will accept your correction .
#
# Spanish:	Véanse 1 Corintios <unk> ; 2 Nefi 2:8 ; Helamán <unk> ; Mormón 9:13 .
# Translation:	See 1 Corinthians 13:8 ; Jacob 2:8 ; Helaman 2:8 ; Helaman 5:12 .
# Target:		See 1 Corinthians <unk> ; 2 Nephi 2:8 ; Helaman <unk> ; Mormon 9:13 .
#
# Spanish:	Véase 1 Corintios 12 ; <unk> ; Moroni <unk> ; Doctrina y Convenios <unk> .
# Translation:	See 1 Corinthians 13:8 ; Moroni 10:32–33 ; Doctrine and Covenants 20:37 .
# Target:		See 1 Corinthians 12 ; <unk> ; Moroni <unk> ; Doctrine and Covenants <unk> .
#
# Spanish:	pero cuando me <unk> los dedos al intentarlo , se me cayó el petardo .
# Translation:	But when he did , I would be able to get back .
# Spanish:	Pero hay una bendición de aliento para los que sirven bajo la influencia del Espíritu .
# Translation:	But there is a blessing for you serve in the influence of the Spirit .
# Target:		But there is a blessing of encouragement for those who serve under the influence of the Spirit .
#
# Spanish:	Nos encontrábamos allí , pero en realidad todavía no sabía cómo valorar esa maravillosa oportunidad .
# Translation:	We were there , but it was not only only to be a wonderful opportunity .
# Target:		We were there , but I did not really know how to appreciate that wonderful opportunity yet .
#
# Spanish:	¿ Sentir que nos abrace ? ¿ Ser testigos cuando Él ministraba a otras personas ?
# Translation:	Do we do you do you do ?
# Target:		Can you imagine sitting at His feet ? feeling His embrace ? witnessing as He ministered to others ?
#
# Spanish:	Ruego que así sea para todos nosotros ; en el nombre de Jesucristo . Amén .
# Translation:	I pray that we will be all of us in the name of Jesus Christ , amen .
# Target:		I pray that may be so for all of us in the name of the Lord Jesus Christ , amen .
#
# Spanish:	( 49 ) Sidney Going escoge servir en una misión en lugar de jugar al rugby .
# Translation:	( in New Zealand ) A friend in a mission in a mission field .
# Target:		( 49 ) Sidney Going chooses a mission over rugby .
#
# Spanish:	En primer lugar , no se cansen nunca de descubrir o redescubrir las verdades del Evangelio .
# Translation:	The first , not been never been never been never to be the gospel .
# Target:		First , never tire of discovering or rediscovering the truths of the gospel .
#
# Spanish:	Hace poco tuve la oportunidad de visitar a algunas amadas mujeres que están en la prisión .
# Translation:	I was a few days of the opportunity to visit some of the young women .
# Target:		Recently I had the opportunity to visit some beloved women who are in prison .
#
# Spanish:	Se casaron el 17 de diciembre de 1980 , en el Templo de Salt Lake City .
# Translation:	They were married in the Salt Lake Temple .
# Target:		They were married on December 17 , 1980 , in the Salt Lake Temple .
#
# Spanish:	También había demostrado paciencia en una situación que normalmente producía en mí el efecto contrario ” .
# Translation:	It was also taught in a situation that is the effect of me . ”
# Target:		I had shown patience in a circumstance that usually <unk> the opposite from me . ”
#
# Spanish:	Él está presto para ayudar — a cada uno de nosotros — con todas nuestras cargas .
# Translation:	He is to help us — each of us — all our burdens .
# Target:		He stands ready to help — to help each of us — with every burden .
#
# Spanish:	Pero , según cómo se utilicen esos avances , podrían ser una bendición o un <unk> .
# Translation:	But how they are doing these , you may be a blessing or a blessing .
# Target:		Depending on how technology is used , these advances can be a blessing or a <unk> .
#
# Spanish:	Inspirado por estas dos grandes mujeres , caminé hasta el vestíbulo y llamé a mi hermana .
# Translation:	Recently these two young women , I called the boat and I called my sister .
# Target:		Prompted by these two great women , I walked to the foyer and called my sister .
#
# Spanish:	También podrán enseñar y edificar de maneras más significativas a las personas a las que aman .
# Translation:	You can teach and teach ways to the more important than you love .
# Target:		You will also be able to teach and lift those you love in more meaningful ways .
#
# Spanish:	Supo que el mensaje de la Restauración era verdadero y él y su esposa se bautizaron .
# Translation:	He knew that the Restoration was true the true and his wife and his wife .
# Target:		He knew the message of the Restoration was true , and he and his wife were baptized .
#
# Spanish:	¿ Cuáles palabras la <unk> , la edificarán y la ayudarán a permanecer en el sendero ?
# Spanish:	Las fotografías de la conferencia general en Salt Lake City fueron tomadas por Welden C. Andersen , Cody Bell , <unk> Bingham , Ale Borges , Randy Collier , Mark Davis , Craig Dimond , <unk> Edwards , <unk> Larsen , Leslie Nilsson , <unk> Reier y Christina Smith ; fotografía de Yvette Bugingo , cortesía de Yvette Bugingo ; fotografía de Joseph Ssengooba y Joshua Walusimbi , cortesía de Joseph Ssengooba ; fotografía de Joseph Ssengooba y Leif Erickson , cortesía de Leif Erickson ; fotografía de los niños y de la reunión de la Iglesia en el Congo , cortesía de Neil L. Andersen y del Área África Sudeste ; fotografía de la joven en la ventana , por <unk> Harmon ; fotografías de Fernando <unk> con jóvenes y de la familia <unk> , cortesía de Fernando <unk> ; fotografía de Russell M. Nelson , la hermana Nelson y la familia de Jimmy Hatfield , cortesía de Russell M. Nelson ; fotografía de Dresden , Alemania , y de iglesia en ruinas , <unk> <unk> ; fotografía de reconstrucción de iglesia luterana , <unk> ; fotografía de <unk> y niños , <unk> .
# Translation:	The Church Auditing Department , Salt Lake City , and Neil L. Andersen , David A. Bednar , and Linda K. Burton , and Sister Bednar , and Sister Bednar , and his wife , and the organ .
# Target:		<unk> in Salt Lake City were taken by Welden C. Andersen , Cody Bell , <unk> Bingham , Ale Borges , Randy Collier , Mark Davis , Craig Dimond , <unk> Edwards , <unk> Larsen , Leslie Nilsson , Matt Reier , and Christina Smith ; of Yvette Bugingo , courtesy of Yvette Bugingo ; of Joseph Ssengooba and Joshua Walusimbi , courtesy of Joseph Ssengooba ; of Joseph Ssengooba and Leif Erickson , courtesy of Leif Erickson ; of children and Church meeting in the Congo , courtesy of Neil L. Andersen and the Africa Southeast Area ; of girl at window , by <unk> Harmon ; of Fernando <unk> with young men and <unk> family , courtesy of Fernando <unk> ; of Russell M. Nelson , Sister Nelson , and the Jimmy Hatfield family , courtesy of Russell M. Nelson ; of Dresden , Germany , and church in ruins , <unk> <unk> ; of rebuilt Lutheran church , <unk> ; of <unk> and children , <unk> .

# %% [markdown]
# <div id="disqus_thread"></div>
# <script>
#     /**
#      *  RECOMMENDED CONFIGURATION VARIABLES: EDIT AND UNCOMMENT THE SECTION BELOW TO INSERT DYNAMIC VALUES FROM YOUR PLATFORM OR CMS.
#      *  LEARN WHY DEFINING THESE VARIABLES IS IMPORTANT: https://disqus.com/admin/universalcode/#configuration-variables
#      */
#     /*
#     var disqus_config = function () {
#         this.page.url = PAGE_URL;  // Replace PAGE_URL with your page's canonical URL variable
#         this.page.identifier = PAGE_IDENTIFIER; // Replace PAGE_IDENTIFIER with your page's unique identifier variable
#     };
#     */
#     (function() {  // REQUIRED CONFIGURATION VARIABLE: EDIT THE SHORTNAME BELOW
#         var d = document, s = d.createElement('script');
#
#         s.src = 'https://EXAMPLE.disqus.com/embed.js';  // IMPORTANT: Replace EXAMPLE with your forum shortname!
#
#         s.setAttribute('data-timestamp', +new Date());
#         (d.head || d.body).appendChild(s);
#     })();
# </script>
# <noscript>Please enable JavaScript to view the <a href="https://disqus.com/?ref_noscript" rel="nofollow">comments powered by Disqus.</a></noscript>
